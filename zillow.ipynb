# %%
import pandas as pd
import numpy as np

# Exploring
import scipy.stats as stats

# Visualizing
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# default pandas decimal number display format
pd.options.display.float_format = '{:20,.2f}'.format

from wrangle import new_zillow_data, get_zillow_data

# %%
df = get_zillow_data()
df.head().T
# Out:
# /Users/derekbixby/codeup-data-science/clustering_exercises/wrangle.py:38: DtypeWarning: Columns (67,69,75,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('zillow.csv', index_col=0)
#                                  0         1         2         3  \
# id                         1727539   1387261     11677   2288172
# parcelid                  14297519  17052889  14186244  12177905
# airconditioningtypeid          NaN       NaN       NaN       NaN
# architecturalstyletypeid       NaN       NaN       NaN       NaN
# basementsqft                   NaN       NaN       NaN       NaN
# ...                            ...       ...       ...       ...
# storytypeid.1                  NaN       NaN       NaN       NaN
# storydesc                      NaN       NaN       NaN       NaN
# typeconstructiontypeid.1       NaN       NaN       NaN       NaN
# typeconstructiondesc           NaN       NaN       NaN       NaN
# parcelid.2                14297519  17052889  14186244  12177905
#
#                                             4
# id                                    1970746
# parcelid                             10887214
# airconditioningtypeid                    1.00
# architecturalstyletypeid                  NaN
# basementsqft                              NaN
# ...                                       ...
# storytypeid.1                             NaN
# storydesc                                 NaN
# typeconstructiontypeid.1                  NaN
# typeconstructiondesc                      NaN
# parcelid.2                           10887214
#
# [78 rows x 5 columns]

# %%
df.T
# Out:
#                              0         1         2         3      \
# id                         1727539   1387261     11677   2288172
# parcelid                  14297519  17052889  14186244  12177905
# airconditioningtypeid          NaN       NaN       NaN       NaN
# architecturalstyletypeid       NaN       NaN       NaN       NaN
# basementsqft                   NaN       NaN       NaN       NaN
# ...                            ...       ...       ...       ...
# storytypeid.1                  NaN       NaN       NaN       NaN
# storydesc                      NaN       NaN       NaN       NaN
# typeconstructiontypeid.1       NaN       NaN       NaN       NaN
# typeconstructiondesc           NaN       NaN       NaN       NaN
# parcelid.2                14297519  17052889  14186244  12177905
#
#                                         4                    5         6      \
# id                                    1970746               781532    870991
# parcelid                             10887214             12095076  12069064
# airconditioningtypeid                    1.00                 1.00       NaN
# architecturalstyletypeid                  NaN                  NaN       NaN
# basementsqft                              NaN                  NaN       NaN
# ...                                       ...                  ...       ...
# storytypeid.1                             NaN                  NaN       NaN
# storydesc                                 NaN                  NaN       NaN
# typeconstructiontypeid.1                  NaN                  NaN       NaN
# typeconstructiondesc                      NaN                  NaN       NaN
# parcelid.2                           10887214             12095076  12069064
#
#                              7         8                    9      ...  \
# id                         1246926   1585097              1639362  ...
# parcelid                  12790562  11542646             11104527  ...
# airconditioningtypeid          NaN       NaN                 1.00  ...
# architecturalstyletypeid       NaN       NaN                  NaN  ...
# basementsqft                   NaN       NaN                  NaN  ...
# ...                            ...       ...                  ...  ...
# storytypeid.1                  NaN       NaN                  NaN  ...
# storydesc                      NaN       NaN                  NaN  ...
# typeconstructiontypeid.1       NaN       NaN                  NaN  ...
# typeconstructiondesc           NaN       NaN                  NaN  ...
# parcelid.2                12790562  11542646             11104527  ...
#
#                              66028                66029                66030  \
# id                         1684937              1642435              1373391
# parcelid                  12666457             10858613             10722691
# airconditioningtypeid          NaN                 1.00                 1.00
# architecturalstyletypeid       NaN                  NaN                  NaN
# basementsqft                   NaN                  NaN                  NaN
# ...                            ...                  ...                  ...
# storytypeid.1                  NaN                  NaN                  NaN
# storydesc                      NaN                  NaN                  NaN
# typeconstructiontypeid.1       NaN                  NaN                  NaN
# typeconstructiondesc           NaN                  NaN                  NaN
# parcelid.2                12666457             10858613             10722691
#
#                              66031                66032     66033     66034  \
# id                         2274245              2864704    673515   2968375
# parcelid                  12412492             10833991  11000655  17239384
# airconditioningtypeid          NaN                 1.00       NaN       NaN
# architecturalstyletypeid       NaN                  NaN       NaN       NaN
# basementsqft                   NaN                  NaN       NaN       NaN
# ...                            ...                  ...       ...       ...
# storytypeid.1                  NaN                  NaN       NaN       NaN
# storydesc                      NaN                  NaN       NaN       NaN
# typeconstructiontypeid.1       NaN                  NaN       NaN       NaN
# typeconstructiondesc           NaN                  NaN       NaN       NaN
# parcelid.2                12412492             10833991  11000655  17239384
#
#                                         66035     66036     66037
# id                                    1843709   1187175   2455685
# parcelid                             12773139  12826780  13083743
# airconditioningtypeid                    1.00       NaN       NaN
# architecturalstyletypeid                  NaN       NaN       NaN
# basementsqft                              NaN       NaN       NaN
# ...                                       ...       ...       ...
# storytypeid.1                             NaN       NaN       NaN
# storydesc                                 NaN       NaN       NaN
# typeconstructiontypeid.1                  NaN       NaN       NaN
# typeconstructiondesc                      NaN       NaN       NaN
# parcelid.2                           12773139  12826780  13083743
#
# [78 rows x 66038 columns]

# %%
df = df.drop_duplicates(subset='parcelid', keep='last')

# %%
df
# Out:
#             id  parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0      1727539  14297519                    NaN                       NaN
# 1      1387261  17052889                    NaN                       NaN
# 2        11677  14186244                    NaN                       NaN
# 3      2288172  12177905                    NaN                       NaN
# 4      1970746  10887214                   1.00                       NaN
# ...        ...       ...                    ...                       ...
# 66033   673515  11000655                    NaN                       NaN
# 66034  2968375  17239384                    NaN                       NaN
# 66035  1843709  12773139                   1.00                       NaN
# 66036  1187175  12826780                    NaN                       NaN
# 66037  2455685  13083743                    NaN                       NaN
#
#        basementsqft          bathroomcnt           bedroomcnt  \
# 0               NaN                 3.50                 4.00
# 1               NaN                 1.00                 2.00
# 2               NaN                 2.00                 3.00
# 3               NaN                 3.00                 4.00
# 4               NaN                 3.00                 3.00
# ...             ...                  ...                  ...
# 66033           NaN                 2.00                 2.00
# 66034           NaN                 2.00                 4.00
# 66035           NaN                 1.00                 3.00
# 66036           NaN                 2.00                 3.00
# 66037           NaN                 2.00                 3.00
#
#        buildingclasstypeid  buildingqualitytypeid    calculatedbathnbr  ...  \
# 0                      NaN                    NaN                 3.50  ...
# 1                      NaN                    NaN                 1.00  ...
# 2                      NaN                    NaN                 2.00  ...
# 3                      NaN                   8.00                 3.00  ...
# 4                      NaN                   8.00                 3.00  ...
# ...                    ...                    ...                  ...  ...
# 66033                  NaN                   6.00                 2.00  ...
# 66034                  NaN                    NaN                 2.00  ...
# 66035                  NaN                   4.00                 1.00  ...
# 66036                  NaN                   6.00                 2.00  ...
# 66037                  NaN                   4.00                 2.00  ...
#
#        buildingclassdesc  heatingorsystemtypeid.1  heatingorsystemdesc  \
# 0                    NaN                      NaN                  NaN
# 1                    NaN                      NaN                  NaN
# 2                    NaN                      NaN                  NaN
# 3                    NaN                     2.00              Central
# 4                    NaN                     2.00              Central
# ...                  ...                      ...                  ...
# 66033                NaN                     2.00              Central
# 66034                NaN                      NaN                  NaN
# 66035                NaN                     2.00              Central
# 66036                NaN                     2.00              Central
# 66037                NaN                     7.00           Floor/Wall
#
#        propertylandusetypeid.1        propertylandusedesc  storytypeid.1  \
# 0                          261  Single Family Residential            NaN
# 1                          261  Single Family Residential            NaN
# 2                          261  Single Family Residential            NaN
# 3                          261  Single Family Residential            NaN
# 4                          266                Condominium            NaN
# ...                        ...                        ...            ...
# 66033                      261  Single Family Residential            NaN
# 66034                      261  Single Family Residential            NaN
# 66035                      261  Single Family Residential            NaN
# 66036                      261  Single Family Residential            NaN
# 66037                      261  Single Family Residential            NaN
#
#        storydesc  typeconstructiontypeid.1  typeconstructiondesc  parcelid.2
# 0            NaN                       NaN                   NaN    14297519
# 1            NaN                       NaN                   NaN    17052889
# 2            NaN                       NaN                   NaN    14186244
# 3            NaN                       NaN                   NaN    12177905
# 4            NaN                       NaN                   NaN    10887214
# ...          ...                       ...                   ...         ...
# 66033        NaN                       NaN                   NaN    11000655
# 66034        NaN                       NaN                   NaN    17239384
# 66035        NaN                       NaN                   NaN    12773139
# 66036        NaN                       NaN                   NaN    12826780
# 66037        NaN                       NaN                   NaN    13083743
#
# [65879 rows x 78 columns]

# %%
df = df.dropna(subset=['longitude', 'latitude'])
df
# Out:
#             id  parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0      1727539  14297519                    NaN                       NaN
# 1      1387261  17052889                    NaN                       NaN
# 2        11677  14186244                    NaN                       NaN
# 3      2288172  12177905                    NaN                       NaN
# 4      1970746  10887214                   1.00                       NaN
# ...        ...       ...                    ...                       ...
# 66033   673515  11000655                    NaN                       NaN
# 66034  2968375  17239384                    NaN                       NaN
# 66035  1843709  12773139                   1.00                       NaN
# 66036  1187175  12826780                    NaN                       NaN
# 66037  2455685  13083743                    NaN                       NaN
#
#        basementsqft          bathroomcnt           bedroomcnt  \
# 0               NaN                 3.50                 4.00
# 1               NaN                 1.00                 2.00
# 2               NaN                 2.00                 3.00
# 3               NaN                 3.00                 4.00
# 4               NaN                 3.00                 3.00
# ...             ...                  ...                  ...
# 66033           NaN                 2.00                 2.00
# 66034           NaN                 2.00                 4.00
# 66035           NaN                 1.00                 3.00
# 66036           NaN                 2.00                 3.00
# 66037           NaN                 2.00                 3.00
#
#        buildingclasstypeid  buildingqualitytypeid    calculatedbathnbr  ...  \
# 0                      NaN                    NaN                 3.50  ...
# 1                      NaN                    NaN                 1.00  ...
# 2                      NaN                    NaN                 2.00  ...
# 3                      NaN                   8.00                 3.00  ...
# 4                      NaN                   8.00                 3.00  ...
# ...                    ...                    ...                  ...  ...
# 66033                  NaN                   6.00                 2.00  ...
# 66034                  NaN                    NaN                 2.00  ...
# 66035                  NaN                   4.00                 1.00  ...
# 66036                  NaN                   6.00                 2.00  ...
# 66037                  NaN                   4.00                 2.00  ...
#
#        buildingclassdesc  heatingorsystemtypeid.1  heatingorsystemdesc  \
# 0                    NaN                      NaN                  NaN
# 1                    NaN                      NaN                  NaN
# 2                    NaN                      NaN                  NaN
# 3                    NaN                     2.00              Central
# 4                    NaN                     2.00              Central
# ...                  ...                      ...                  ...
# 66033                NaN                     2.00              Central
# 66034                NaN                      NaN                  NaN
# 66035                NaN                     2.00              Central
# 66036                NaN                     2.00              Central
# 66037                NaN                     7.00           Floor/Wall
#
#        propertylandusetypeid.1        propertylandusedesc  storytypeid.1  \
# 0                          261  Single Family Residential            NaN
# 1                          261  Single Family Residential            NaN
# 2                          261  Single Family Residential            NaN
# 3                          261  Single Family Residential            NaN
# 4                          266                Condominium            NaN
# ...                        ...                        ...            ...
# 66033                      261  Single Family Residential            NaN
# 66034                      261  Single Family Residential            NaN
# 66035                      261  Single Family Residential            NaN
# 66036                      261  Single Family Residential            NaN
# 66037                      261  Single Family Residential            NaN
#
#        storydesc  typeconstructiontypeid.1  typeconstructiondesc  parcelid.2
# 0            NaN                       NaN                   NaN    14297519
# 1            NaN                       NaN                   NaN    17052889
# 2            NaN                       NaN                   NaN    14186244
# 3            NaN                       NaN                   NaN    12177905
# 4            NaN                       NaN                   NaN    10887214
# ...          ...                       ...                   ...         ...
# 66033        NaN                       NaN                   NaN    11000655
# 66034        NaN                       NaN                   NaN    17239384
# 66035        NaN                       NaN                   NaN    12773139
# 66036        NaN                       NaN                   NaN    12826780
# 66037        NaN                       NaN                   NaN    13083743
#
# [65879 rows x 78 columns]

# %%
def handle_missing_values(df, prop_required_column = .5, prop_required_row = .70):
    threshold = int(round(prop_required_column*len(df.index),0))
    df.dropna(axis=1, thresh=threshold, inplace=True)
    threshold = int(round(prop_required_row*len(df.columns),0))
    df.dropna(axis=0, thresh=threshold, inplace=True)
    return df

# %%
handle_missing_values(df)
# Out:
#             id  parcelid          bathroomcnt           bedroomcnt  \
# 0      1727539  14297519                 3.50                 4.00
# 1      1387261  17052889                 1.00                 2.00
# 2        11677  14186244                 2.00                 3.00
# 3      2288172  12177905                 3.00                 4.00
# 4      1970746  10887214                 3.00                 3.00
# ...        ...       ...                  ...                  ...
# 66033   673515  11000655                 2.00                 2.00
# 66034  2968375  17239384                 2.00                 4.00
# 66035  1843709  12773139                 1.00                 3.00
# 66036  1187175  12826780                 2.00                 3.00
# 66037  2455685  13083743                 2.00                 3.00
#
#        buildingqualitytypeid    calculatedbathnbr  \
# 0                        NaN                 3.50
# 1                        NaN                 1.00
# 2                        NaN                 2.00
# 3                       8.00                 3.00
# 4                       8.00                 3.00
# ...                      ...                  ...
# 66033                   6.00                 2.00
# 66034                    NaN                 2.00
# 66035                   4.00                 1.00
# 66036                   6.00                 2.00
# 66037                   4.00                 2.00
#
#        calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                          3,100.00              3,100.00
# 1                          1,465.00              1,465.00
# 2                          1,243.00              1,243.00
# 3                          2,376.00              2,376.00
# 4                          1,312.00              1,312.00
# ...                             ...                   ...
# 66033                      1,286.00              1,286.00
# 66034                      1,612.00              1,612.00
# 66035                      1,032.00              1,032.00
# 66036                      1,762.00              1,762.00
# 66037                      1,050.00              1,050.00
#
#                       fips          fullbathcnt  ...   censustractandblock  \
# 0                 6,059.00                 3.00  ... 60,590,630,072,012.00
# 1                 6,111.00                 1.00  ... 61,110,010,023,006.00
# 2                 6,059.00                 2.00  ... 60,590,218,022,012.00
# 3                 6,037.00                 3.00  ... 60,373,001,001,006.00
# 4                 6,037.00                 3.00  ... 60,371,236,012,000.00
# ...                    ...                  ...  ...                   ...
# 66033             6,037.00                 2.00  ... 60,371,014,003,002.00
# 66034             6,111.00                 2.00  ... 61,110,084,022,016.00
# 66035             6,037.00                 1.00  ... 60,374,338,022,005.00
# 66036             6,037.00                 2.00  ... 60,375,034,021,020.00
# 66037             6,037.00                 2.00  ... 60,374,081,401,000.00
#
#         id.1  parcelid.1             logerror transactiondate  \
# 0          0    14297519                 0.03      2017-01-01
# 1          1    17052889                 0.06      2017-01-01
# 2          2    14186244                 0.01      2017-01-01
# 3          3    12177905                -0.10      2017-01-01
# 4          4    10887214                 0.01      2017-01-01
# ...      ...         ...                  ...             ...
# 66033  77609    11000655                 0.02      2017-09-20
# 66034  77610    17239384                 0.01      2017-09-21
# 66035  77611    12773139                 0.04      2017-09-21
# 66036  77612    12826780                 0.01      2017-09-25
# 66037  77613    13083743                -0.20      2018-05-25
#
#        heatingorsystemtypeid.1 heatingorsystemdesc  propertylandusetypeid.1  \
# 0                          NaN                 NaN                      261
# 1                          NaN                 NaN                      261
# 2                          NaN                 NaN                      261
# 3                         2.00             Central                      261
# 4                         2.00             Central                      266
# ...                        ...                 ...                      ...
# 66033                     2.00             Central                      261
# 66034                      NaN                 NaN                      261
# 66035                     2.00             Central                      261
# 66036                     2.00             Central                      261
# 66037                     7.00          Floor/Wall                      261
#
#              propertylandusedesc  parcelid.2
# 0      Single Family Residential    14297519
# 1      Single Family Residential    17052889
# 2      Single Family Residential    14186244
# 3      Single Family Residential    12177905
# 4                    Condominium    10887214
# ...                          ...         ...
# 66033  Single Family Residential    11000655
# 66034  Single Family Residential    17239384
# 66035  Single Family Residential    12773139
# 66036  Single Family Residential    12826780
# 66037  Single Family Residential    13083743
#
# [65872 rows x 39 columns]
